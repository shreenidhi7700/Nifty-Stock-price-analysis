# %% [markdown]
# # Maruti_Suzuki_Stock_Price_Analysis

# %% [markdown]
# In this notebook, we’ll use it to analyze stock prices of Maruti and perform some basic time series operations. **`Maruti Suzuki India`** Limited, formerly known as **`Maruti Udyog`** Limited, is an automobile manufacturer in India. It is a **56.21%** owned subsidiary of the Japanese car and motorcycle manufacturer **`Suzuki Motor Corporation`**. As of **July 2018**, it had a market share of **53%** of the Indian passenger car market.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_link = "https://github.com/shreenidhi7700/Nifty-Stock-price-analysis/raw/refs/heads/master/MARUTI.csv"

# %%
dt = pd.read_csv(data_link)
dt.head()
# Out:
#          Date  Symbol Series  Prev Close    Open    High     Low   Last  \
# 0  2003-07-09  MARUTI     EQ      125.00  164.90  170.40  155.00  164.0
# 1  2003-07-10  MARUTI     EQ      164.30  167.00  168.70  164.50  167.0
# 2  2003-07-11  MARUTI     EQ      167.00  167.75  174.85  166.25  173.6
# 3  2003-07-14  MARUTI     EQ      173.35  174.25  179.25  174.25  178.6
# 4  2003-07-15  MARUTI     EQ      177.95  200.00  200.00  173.00  176.3
#
#     Close    VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# 0  164.30  165.95  35164283  5.835528e+14     NaN           8537695.0
# 1  167.00  166.74  10464179  1.744820e+14     NaN           4363947.0
# 2  173.35  172.45  11740117  2.024622e+14     NaN           3014852.0
# 3  177.95  177.91   5982324  1.064313e+14     NaN           1949217.0
# 4  176.20  176.88   6173689  1.092001e+14     NaN           1307694.0
#
#    %Deliverble
# 0       0.2428
# 1       0.4170
# 2       0.2568
# 3       0.3258
# 4       0.2118

# %%
dt.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
dt.shape
# Out:
# (4305, 15)

# %%
dt.Date
# Out:
# 0       2003-07-09
# 1       2003-07-10
# 2       2003-07-11
# 3       2003-07-14
# 4       2003-07-15
#            ...
# 4300    2020-10-26
# 4301    2020-10-27
# 4302    2020-10-28
# 4303    2020-10-29
# 4304    2020-10-30
# Name: Date, Length: 4305, dtype: object

# %%
dt.isnull().sum()
# Out:
# Date                     0
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                1971
# Deliverable Volume       1
# %Deliverble              1
# dtype: int64

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4305 entries, 0 to 4304
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                4305 non-null   object
#  1   Symbol              4305 non-null   object
#  2   Series              4305 non-null   object
#  3   Prev Close          4305 non-null   float64
#  4   Open                4305 non-null   float64
#  5   High                4305 non-null   float64
#  6   Low                 4305 non-null   float64
#  7   Last                4305 non-null   float64
#  8   Close               4305 non-null   float64
#  9   VWAP                4305 non-null   float64
#  10  Volume              4305 non-null   int64
#  11  Turnover            4305 non-null   float64
#  12  Trades              2334 non-null   float64
#  13  Deliverable Volume  4304 non-null   float64
#  14  %Deliverble         4304 non-null   float64
# ...

# %%
# For the Analysis purpose we will focus on these columns

dt = dt[['Date','Open','High','Low','Close','Volume','VWAP']]
dt.head()
# Out:
#          Date    Open    High     Low   Close    Volume    VWAP
# 0  2003-07-09  164.90  170.40  155.00  164.30  35164283  165.95
# 1  2003-07-10  167.00  168.70  164.50  167.00  10464179  166.74
# 2  2003-07-11  167.75  174.85  166.25  173.35  11740117  172.45
# 3  2003-07-14  174.25  179.25  174.25  177.95   5982324  177.91
# 4  2003-07-15  200.00  200.00  173.00  176.20   6173689  176.88

# %% [markdown]
# Now we will convert the `Date` column from **string\object** datatype to **datetime** datatype which will be useful for our time series analysis

# %%
dt.Date = pd.to_datetime(dt.Date)
dt.Date
# Out:
# 0      2003-07-09
# 1      2003-07-10
# 2      2003-07-11
# 3      2003-07-14
# 4      2003-07-15
#           ...
# 4300   2020-10-26
# 4301   2020-10-27
# 4302   2020-10-28
# 4303   2020-10-29
# 4304   2020-10-30
# Name: Date, Length: 4305, dtype: datetime64[ns]

# %%
# setting the index of our dataframe to Date column
dt.set_index('Date', inplace = True)
dt.head()
# Out:
#               Open    High     Low   Close    Volume    VWAP
# Date
# 2003-07-09  164.90  170.40  155.00  164.30  35164283  165.95
# 2003-07-10  167.00  168.70  164.50  167.00  10464179  166.74
# 2003-07-11  167.75  174.85  166.25  173.35  11740117  172.45
# 2003-07-14  174.25  179.25  174.25  177.95   5982324  177.91
# 2003-07-15  200.00  200.00  173.00  176.20   6173689  176.88

# %% [markdown]
# ### About the Stock Data¶
#
# Now that our data has been converted into the desired format, let’s take a look at its various columns for further analysis.
#
# - The **`Open`** and **`Close`** columns indicate the opening and closing price of the stocks on a particular day.
# - The **`High`** and **`Low`** columns provide the highest and the lowest price for the stock on a particular day, respectively.
# - The **`Volume`** column tells us the total volume of stocks traded on a particular day.
# - The **`volume weighted average price (VWAP)`** is a trading benchmark used by traders that gives the average price a security has traded at throughout the day, based on both volume and price. It is important because it provides traders with insight into both the trend and value of a security.

# %% [markdown]
# ## Visualizing Our Time Series Data

# %%
dt['VWAP'].plot(figsize = (15,6), title = 'Maruti Stock Prices', ylabel = 'VWAP', color = 'r')
plt.show()

# %% [markdown]
# There has been a steady increase in `Maruti's Stock prices` except a slimp around **2019**.

# %%
from datetime import datetime

# %%
mytime = datetime(1999,8,25,4,30,0)
mytime
# Out:
# datetime.datetime(1999, 8, 25, 4, 30)

# %%
mytime.year, mytime.month, mytime.day
# Out:
# (1999, 8, 25)

# %%
mytime.hour, mytime.minute
# Out:
# (4, 30)

# %%
datetime.today()
# Out:
# datetime.datetime(2025, 1, 4, 13, 24, 48, 287448)

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 1, 4, 13, 24, 55, 599970)

# %%
# Maximum and Minimum date and time from our dataset

dt.index.min(), dt.index.max()
# Out:
# (Timestamp('2003-07-09 00:00:00'), Timestamp('2020-10-30 00:00:00'))

# %%
dt.index.argmin(), dt.index.argmax()
# Out:
# (0, 4304)

# %%
dt_vwap = dt[['VWAP']]
dt_vwap.sort_index()
# Out:
#                VWAP
# Date
# 2003-07-09   165.95
# 2003-07-10   166.74
# 2003-07-11   172.45
# 2003-07-14   177.91
# 2003-07-15   176.88
# ...             ...
# 2020-10-26  7056.34
# 2020-10-27  7139.86
# 2020-10-28  7240.73
# 2020-10-29  7092.42
# 2020-10-30  6979.63
#
# [4305 rows x 1 columns]

# %%
# Slicing a year
dt_vwap['2015':'2016']

# Slicing by month
dt_vwap['2016-01':'2016-02']

# Slicing on day
dt_vwap['2016-01-01':'2016-01-12']
# Out:
#                VWAP
# Date
# 2016-01-01  4640.33
# 2016-01-04  4605.24
# 2016-01-05  4576.38
# 2016-01-06  4529.56
# 2016-01-07  4300.52
# 2016-01-08  4241.34
# 2016-01-11  4249.00
# 2016-01-12  4285.12

# %%
dt_vwap.plot(figsize = (15,6), color = 'b', xlabel = 'Date', ylabel = 'VWAP')
plt.axvspan('2019-01-01','2020-01-01', color = 'red', alpha = 0.4)
plt.axvspan('2016-01-01','2018-01-01', color = 'orange', alpha = 0.4)
plt.axhspan(6000, 7000, color = 'green', alpha = 0.1)

plt.show()

# %% [markdown]
# It appears that Maruti had a more or less steady increase in its stock price over the from 2004 to the mid of 2018 window.There appears to be some drop in 2019 though.let's further analyse the data for the year 2018.

# %% [markdown]
# ## Visulaizing using KDE's

# %% [markdown]
# Summarizing the data with Density plots to see where the mass of the data is located

# %%
import seaborn as sns

sns.kdeplot(dt_vwap['VWAP'], color = 'purple',fill = True)
plt.show()

# %%
dt_vwap.loc['2018','VWAP'].plot(figsize = (15,6), title = 'Month-wise Trend in 2018', color = 'darkgreen', ylabel = 'VWAP', xlabel = 'Date')
dt_vwap.loc['2019','VWAP'].plot(figsize = (15,6), title = 'Month-wise Trend in 2018', color = 'darkblue', ylabel = 'VWAP', xlabel = 'Date')
dt_vwap.loc['2020','VWAP'].plot(figsize = (15,6), title = 'Month-wise Trend in 2018', color = 'brown', ylabel = 'VWAP', xlabel = 'Date')
plt.axvline('2018-01-01', color = 'k', linestyle = 'dotted', lw = 1.5)
plt.axvline('2019-01-01', color = 'k', linestyle = 'dotted', lw = 1.5)
plt.axvline('2020-01-01', color = 'k', linestyle = 'dotted', lw = 1.5)
plt.axvline(dt.index.max(), color = 'k', linestyle = 'dotted', lw = 1.5)
plt.show()

# %% [markdown]
# We can see that there was a dip in the stock prices particularly around end of **`February`** and **`May`**.

# %%
dt_vwap.loc['2020-03-01':'2020-06-01'].plot(figsize = (15,6), marker = 'o', title = 'Month-wise Trend in 2018', color = 'darkred', ylabel = 'VWAP', xlabel = 'Date')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Time-series seasonal decomposition

# %% [markdown]
# We can decompose a time series into **trend, seasonal amd remainder components**, the series can be decomposed as an additive or multiplicative combination of the **base level, trend, seasonal index and the residual**.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse

# %%
y = dt_vwap['VWAP'].to_frame()

# Multiplicative Decomposition
result_mul = seasonal_decompose(y, model = 'multiplicative', period = 52)

# Additive Decomposition
result_add = seasonal_decompose(y, model = 'additive', period = 52)

plt.rcParams['figure.figsize'] = (15,12)
result_mul.plot()
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15,12)
result_add.plot()
plt.show()

# %% [markdown]
# Here **`Multiplicative Model`** is the best model for time series analysis, because the seasonal fluctuations in your data grow with the **trend**, indicating proportionality that the multiplicative model handles better.

# %%
dt_vwap.resample(rule = 'YE').mean()
# Out:
#                    VWAP
# Date
# 2003-12-31   266.608468
# 2004-12-31   430.522835
# 2005-12-31   494.328566
# 2006-12-31   845.582160
# 2007-12-31   887.107871
# 2008-12-31   702.865285
# 2009-12-31  1126.175638
# 2010-12-31  1377.567540
# 2011-12-31  1163.060891
# 2012-12-31  1266.256335
# 2013-12-31  1515.124520
# 2014-12-31  2467.851189
# 2015-12-31  4037.128347
# 2016-12-31  4515.793401
# 2017-12-31  7236.069516
# 2018-12-31  8564.463659
# 2019-12-31  6790.216490
# 2020-12-31  6220.712571

# %%
dt_vwap.resample(rule = 'YE').mean().plot(kind = 'bar',figsize = (15,5), edgecolor = 'k', lw = 0.6, color = 'orange')
# Out:
# <Axes: xlabel='Date'>

# %%
dt_vwap.resample(rule = 'YS').mean().plot(kind = 'bar', edgecolor = 'k', color = 'green', lw = 0.6, figsize = (15,5))
plt.show()

# %% [markdown]
# ## Time shifting

# %% [markdown]
# Sometimes, we may need to shift or move the data forward or backwards in time. This shifting is done along a time index by the desired number of time-frequency increments.

# %%
dt.shift(3)
# Out:
#               Open     High      Low    Close      Volume     VWAP
# Date
# 2003-07-09     NaN      NaN      NaN      NaN         NaN      NaN
# 2003-07-10     NaN      NaN      NaN      NaN         NaN      NaN
# 2003-07-11     NaN      NaN      NaN      NaN         NaN      NaN
# 2003-07-14   164.9   170.40   155.00   164.30  35164283.0   165.95
# 2003-07-15   167.0   168.70   164.50   167.00  10464179.0   166.74
# ...            ...      ...      ...      ...         ...      ...
# 2020-10-26  6904.0  6947.60  6764.65  6861.85    911969.0  6876.18
# 2020-10-27  6828.0  6860.00  6775.20  6811.55    584542.0  6808.01
# 2020-10-28  6858.0  7124.70  6832.00  7103.25   1758999.0  7021.17
# 2020-10-29  7100.0  7161.30  6935.05  7054.80   1559361.0  7056.34
# 2020-10-30  7067.0  7209.75  7053.00  7158.40   1461819.0  7139.86
#
# [4305 rows x 6 columns]

# %%
dt_vwap.shift(5)
# Out:
#                VWAP
# Date
# 2003-07-09      NaN
# 2003-07-10      NaN
# 2003-07-11      NaN
# 2003-07-14      NaN
# 2003-07-15      NaN
# ...             ...
# 2020-10-26  6873.55
# 2020-10-27  6877.34
# 2020-10-28  6876.18
# 2020-10-29  6808.01
# 2020-10-30  7021.17
#
# [4305 rows x 1 columns]

# %%
ax1 = plt.subplot()
dt_vwap.rolling(window = 30).median().plot(ax = ax1,color = 'red', figsize = (15,6))
dt_vwap.rolling(window = 50).median().plot(ax = ax1,color = 'orange', figsize = (15,6))
dt_vwap.rolling(window = 100).median().plot(ax = ax1,color = 'blue', figsize = (15,6))
dt_vwap.plot(ax = ax1, color = 'k')

plt.show()
